# %%
from .Cifar10DataIO import*
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ResNet.Cirfar10DataIO import*
#
# ModuleNotFoundError: No module named 'ResNet.Cirfar10DataIO'; 'ResNet' is not a package

# %%
data_size = 100
train_loader, valid_loader = data_loader(data_dir='./data',
                                             batch_size=batch_size,
                                             test_only=False,
                                             training_data_size=data_size,
                                             test_data_size=data_size)
